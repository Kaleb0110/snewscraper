# %%
from bs4 import BeautifulSoup
import urllib.request
from docx import Document
from datetime import datetime
from urllib.error import HTTPError

# %%
url = 'https://www.thestandard.com.hk/newsfeed/latest/news.xml'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'xml')
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rss version="2.0">
# <channel>
# <title>The Standard - Latest News</title>
# <link>http://www.thestandard.com.hk</link>
# <description>Latest headlines from The Standard</description>
# <pubDate>Fri, 31 Jan 2020 10:10:22 +0800</pubDate>
# <generator>RSS newsfeed by The Standard</generator>
# <copyright>The Standard, Sing Tao News Corp.</copyright>
# <managingEditor>editor@thestandard.com.hk</managingEditor>
# <webMaster>todd.john@singtaonewscorp.com</webMaster>
#
# <title>The Standard</title>
# <url>http://www.thestandard.com.hk/url_to_some_image.gif</url>
# <link>http://www.thestandard.com.hk</link>
#
# <item>
# <title>China to soften viral blow to economy</title>
# <link>http://www.thestandard.com.hk/section-news.php?id=215831&amp;sid=2&amp;sid=2</link>
# Authorities will need to break their fiscal rule of a 3 percent deficit relative to GDP to "slow the downward...</description>
# <pubDate>Fri, 31 Jan 2020 00:00:00 +0800</pubDate>
# ...

# %%
soup.find_all('link')
# Out:
# [<link>http://www.thestandard.com.hk</link>,
#  <link>http://www.thestandard.com.hk</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215831&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215830&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215829&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215828&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215827&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215826&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215825&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215824&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215823&amp;sid=2&amp;sid=2</link>,
# ...

# %%
test_url = 'http://www.thestandard.com.hk/section-news.php?id=215739&amp;sid=2&amp;sid=2'
test_news_page = urllib.request.urlopen(test_url)
test_news_soup = BeautifulSoup(test_news_page, 'html')
test_news_soup.find_all('p')
# Out:
# [<p>BOC shells out 3.9m euros to settle probe</p>,
#  <p>Bank of China (3988) agreed to pay 3.9 million euros (HK$33.40 million) to settle a French probe into allegations it turned a blind eye as customers moved millions to their Asian accounts without paying European taxes.</p>,
#  <p>
#  Paris prosecutor Remi Heitz said Bank of China will pay a 3 million-euro fine and 900,000 euros in damages to French tax authorities to end the criminal prosecution. The case against 28 business owners and intermediaries involved in transferring the funds to China will continue, Heitz said yesterday in a statement. </p>,
#  <p>
#  The Beijing-based bank had been charged with aggravated money laundering over the transfer of suspect funds worth nearly 40 million euros to 168 Bank of China accounts mostly in Zhejiang province between 2012 and 2014. Those charges are dropped as part of the settlement, which was approved by a Paris judge on January 15 and is now final.</p>,
#  <p>
# ...

# %%
test_news_soup.find_all('p')[:-2][0].contents
# Out:
# ['BOC shells out 3.9m euros to settle probe']

# %%
soup.find_all('link')
# Out:
# [<link>http://www.thestandard.com.hk</link>,
#  <link>http://www.thestandard.com.hk</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215831&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215830&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215829&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215828&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215827&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215826&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215825&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215824&amp;sid=2&amp;sid=2</link>,
#  <link>http://www.thestandard.com.hk/section-news.php?id=215823&amp;sid=2&amp;sid=2</link>,
# ...

# %%
list_of_news_html = []

for i,e in enumerate(soup.find_all('link')):
    if i == 0 or i == 1:
        continue
    else:
        try:
            news_page = urllib.request.urlopen(e.contents[0])
            news_soup = BeautifulSoup(news_page, 'lxml')
            print('----------------------------------------------------')
            print(news_soup.find_all('p'))
            list_of_news_html.append(news_soup.find_all('p')[:-2])
        except HTTPError:
            print('Skipping over link because of 404 Error.')
            continue
# Out:
# ----------------------------------------------------
# "It obviously is going to have some ramifications economy-wide, which we hope will not inhibit the purchase goal that we have for this year," US Agriculture Secretary Sonny Perdue said yesterday. "We'll have to look ahead and see. But the honest answer is we just don't know yet."</p>, <p>Today's Standard</p>, <p class="notice-text">ercent earlier.</p>, <p>
#             Trademark and Copyright Notice: Copyright 2020, The Standard Newspaper Publishing Ltd., and its related entities. All rights reserved.
#             <br/>Use in whole or part of this site's content is prohibited. Use of this Web site assumes acceptance of the <a href="http://www.thestandard.com.hk/terms-of-use/" title="Terms of Use">Terms of Use</a>, <a href="http://www.thestandard.com.hk/privacy/" title="Privacy Policy Statement">Privacy Policy Statement</a>
# ...

# %%
list_of_news_html

# %%
news_string = ''
list_of_news = []
for i in list_of_news_html:
    for j,k in enumerate(i):
        news_string += k.contents[0] + '\n'
        if j == (len(i)-1):
            print(news_string)
            list_of_news.append(news_string)
    news_string = ''
list_of_news
# Out:
# China to soften viral blow to economy
# China is expected to unveil efforts to cushion the economic blow from the novel coronavirus, with the central bank set to keep liquidity ample and the government likely to step up spending.
# Authorities will need to break their fiscal rule of a 3 percent deficit relative to GDP to "slow the downward spiral of economic activities," according to Li-Gang Liu at Citigroup.
# Measures such as cutting interest rates and the proportion of deposits banks must set aside as reserves are possible, said Larry Hu, head of China economics at Macquarie Securities in Hong Kong.
# JPMorgan Chase economists led by Zhu Haibin revised their growth forecast for 2020 to factor in the "large negative shock" in the first quarter - mainly to retail sales. They lowered the year-on-year prediction for the first quarter to 5.6 percent from a previous estimate of 6 percent and the 2020 forecast to 5.8 percent from 5.93 percent earlier.
# ...

# %%
list_of_news[0]

# %%
list_of_news[0].split('\n')

# %%
news_doc = Document()
news_doc.add_heading('The Standard Top News',0)
today = datetime.now()
date_string = 'Extracted at ' + today.strftime("%d/%m/%Y %H:%M:%S")
news_doc.add_paragraph(date_string)

for i in list_of_news:
    news_doc.add_heading(i.split('\n')[0], 0)
    print(i)
    p = news_doc.add_paragraph(i)

news_doc.save('demo.docx')
# Out:
# China to soften viral blow to economy
# China is expected to unveil efforts to cushion the economic blow from the novel coronavirus, with the central bank set to keep liquidity ample and the government likely to step up spending.
# Authorities will need to break their fiscal rule of a 3 percent deficit relative to GDP to "slow the downward spiral of economic activities," according to Li-Gang Liu at Citigroup.
# Measures such as cutting interest rates and the proportion of deposits banks must set aside as reserves are possible, said Larry Hu, head of China economics at Macquarie Securities in Hong Kong.
# JPMorgan Chase economists led by Zhu Haibin revised their growth forecast for 2020 to factor in the "large negative shock" in the first quarter - mainly to retail sales. They lowered the year-on-year prediction for the first quarter to 5.6 percent from a previous estimate of 6 percent and the 2020 forecast to 5.8 percent from 5.93 percent earlier.
# ...
